# %% [markdown]
# **Análise do Microdados ENEM 2017**

# %%
import sys
import pandas as pd

# %%
sys.path.append('/home/rayssa/Desktop/Bootcamp-Data-Analytics/Uteis/')

# %%
file_name = '/home/rayssa/Desktop/Bootcamp-Data-Analytics/Datasets/csv/MICRODADOS_ENEM_2017.csv'

# %%
import encoding_separator as es
encoding, sep = es.encoding_separator(file_name=file_name)
print(encoding, sep)
# Out:
# ISO-8859-1 ;

# %%
columns = ['NU_INSCRICAO',
           'NU_ANO',
           'TP_FAIXA_ETARIA',
           'TP_SEXO',
           'TP_ESTADO_CIVIL',
           'TP_COR_RACA',
           'TP_NACIONALIDADE',
           'TP_ESCOLA',
           'NU_NOTA_CN',
           'NU_NOTA_CH',
           'NU_NOTA_LC',
           'NU_NOTA_MT',
           'NU_NOTA_REDACAO',
           ]

enem_df = pd.read_csv(file_name, sep=sep, encoding=encoding, usecols=columns)
display(enem_df)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        170003336736    2017               11       F                1
# 1        170003333545    2017                7       F                1
# 2        170001663644    2017               13       F                1
# 3        170001663645    2017               12       F                1
# 4        170001663646    2017               13       M                1
# ...               ...     ...              ...     ...              ...
# 6731273  170006695639    2017                2       M                1
# 6731274  170006722908    2017                6       F                1
# 6731275  170006718941    2017               15       M                1
# 6731276  170003271006    2017               12       F                1
# 6731277  170006695640    2017                4       M                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ESCOLA  NU_NOTA_CN  NU_NOTA_CH  \
# ...

# %%
enem_df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ESCOLA',
#        'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'NU_NOTA_REDACAO'], dtype=object)

# %%
display(enem_df.loc[(enem_df['TP_FAIXA_ETARIA'] == 4) &
        (enem_df['TP_SEXO'] == 'F') &
        (enem_df['TP_ESTADO_CIVIL'] == 0) &
        (enem_df['TP_COR_RACA'] == 1) &
        (enem_df['TP_NACIONALIDADE'] == 1) &
        (enem_df['TP_ESCOLA'] == 4) &
        (enem_df['NU_NOTA_REDACAO'] == 920)])
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 21       170003336366    2017                4       F                1
# 36       170001664210    2017                4       F                1
# 44       170001671265    2017                4       F                1
# 63       170001664821    2017                4       F                1
# 64       170001664212    2017                4       F                1
# ...               ...     ...              ...     ...              ...
# 6731200  170006724841    2017                4       F                0
# 6731213  170006695628    2017                4       F                0
# 6731240  170006722890    2017                4       F                1
# 6731252  170006722898    2017                4       F                1
# 6731277  170006695640    2017                4       M                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ESCOLA  NU_NOTA_CN  NU_NOTA_CH  \
# ...
